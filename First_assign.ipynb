# %% [markdown]
# <a href="https://colab.research.google.com/github/avishiii28/Dev_Soc_Assign/blob/AIML/First_assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7646cd74-8114-4cc5-a1b0-c0f745b09455" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7646cd74-8114-4cc5-a1b0-c0f745b09455">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# sample_data  text.txt

# %%
with open("text.txt", "r") as f:
    print(f.read())
# Out:
# What is an operating system?
# What is the OSI model?
# Who was Alan Turing?
# How do computer networks work?
# What is the Linux Kernel?
# What is a File system?
# What is Docker?
# What is a GPU and how is it different from a CPU?
# What are the layers of the OSI model?
# What is BeeGFS?
# What are the various components that comprise a computer?
# What is Federated Learning?

# %%
# ----------- SETUP -----------
# Install Google Generative AI library if running in Colab
# !pip install -q google-generativeai

import google.generativeai as genai
import json

genai.configure(api_key="AIzaSyCPujj4dCYkDKkF1wgjYRW9RUoiYizLDnM")

try:
    with open("text.txt", "r") as file:
        prompts = [line.strip() for line in file.readlines() if line.strip()]
except FileNotFoundError:
    print("⚠️ text.txt not found! Please upload or create it first.")
    prompts = []

responses = {}

# Get a list of available models
for model in genai.list_models():
    if 'generateContent' in model.supported_generation_methods:
        print(model.name)

# Replace with a valid model name from the list printed above
valid_model_name = 'gemini-2.5-flash'

for i, prompt in enumerate(prompts, 1):
    print(f"Processing {i}/{len(prompts)} → {prompt}")
    model = genai.GenerativeModel(valid_model_name)
    response = model.generate_content(prompt)
    responses[prompt] = response.text

with open("responses.json", "w") as outfile:
    json.dump(responses, outfile, indent=4)

print("\n✅ Done! All responses saved to 'responses.json'")
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %%
import json

try:
    with open("responses.json", "r") as infile:
        responses_data = json.load(infile)
    display(responses_data)
except FileNotFoundError:
    print("⚠️ responses.json not found! Please run the previous cell to generate it.")
except json.JSONDecodeError:
    print("⚠️ Error decoding JSON from responses.json.")
# Out:
# {'What is an operating system?': "An **operating system (OS)** is the most important software that runs on a computer. It's the **master control program** that manages all of the computer's hardware and software resources, making the computer functional and allowing you to interact with it.\n\nThink of it as the **bridge** between you (the user) or your applications, and the raw computer hardware. Without an operating system, a computer is just a collection of inert hardware components.\n\nHere's a breakdown of what an OS does and why it's essential:\n\n### Key Functions and Roles of an Operating System:\n\n1.  **Resource Management:**\n    *   **CPU (Processor) Management:** The OS decides which program gets to use the CPU when, and for how long. This allows you to run multiple applications seemingly at the same time (multitasking).\n    *   **Memory (RAM) Management:** It allocates memory to different programs as they run, ensuring they don't interfere with each other and that memo
# ...
